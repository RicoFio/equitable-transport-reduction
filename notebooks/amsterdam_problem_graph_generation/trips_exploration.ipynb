# %%
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib.cm as cm
import numpy as np

# %%
df = pd.read_csv('./test_trips.csv')
del df['Unnamed: 0']
df
# Out:
#         trip_id arrival_time departure_time  stop_id  stop_sequence  \
# 0     156905239     06:31:00       06:31:00    15210              1
# 1     156905239     06:31:44       06:31:45    14873              2
# 2     156905239     06:32:52       06:33:10    15070              3
# 3     156905239     06:33:42       06:34:00    15064              4
# 4     156905239     06:34:51       06:35:09  2409628              5
# ...         ...          ...            ...      ...            ...
# 9867  158407476     24:50:07       24:50:25    14967             11
# 9868  158407476     24:51:30       24:51:48    15063             12
# 9869  158407476     24:52:19       24:52:20    15069             13
# 9870  158407476     24:53:41       24:53:59    15071             14
# 9871  158407476     24:55:00       24:55:00    15207             15
#
#       stop_headsign  pickup_type  drop_off_type  shape_dist_traveled  \
# 0               NaN            0              1                  0.0
# ...

# %%
df.groupby('trip_id')['stop_id'].shift(-1).astype(int, errors='ignore')
# Out:
# 0         14873.0
# 1         15070.0
# 2         15064.0
# 3       2409628.0
# 4         14838.0
#           ...
# 9867      15063.0
# 9868      15069.0
# 9869      15071.0
# 9870      15207.0
# 9871          NaN
# Name: stop_id, Length: 9872, dtype: float64

# %%
destinations = df.groupby('trip_id')['stop_id'].shift(-1).astype('Int64', errors='ignore').tolist()
df.insert(loc=4, column='destination', value=destinations)

# %%
df
# Out:
#         trip_id arrival_time departure_time  stop_id destination  \
# 0     156905239     06:31:00       06:31:00    15210       14873
# 1     156905239     06:31:44       06:31:45    14873       15070
# 2     156905239     06:32:52       06:33:10    15070       15064
# 3     156905239     06:33:42       06:34:00    15064     2409628
# 4     156905239     06:34:51       06:35:09  2409628       14838
# ...         ...          ...            ...      ...         ...
# 9867  158407476     24:50:07       24:50:25    14967       15063
# 9868  158407476     24:51:30       24:51:48    15063       15069
# 9869  158407476     24:52:19       24:52:20    15069       15071
# 9870  158407476     24:53:41       24:53:59    15071       15207
# 9871  158407476     24:55:00       24:55:00    15207        <NA>
#
#       stop_sequence  stop_headsign  pickup_type  drop_off_type  \
# 0                 1            NaN            0              1
# ...

# %%
# colors = cm.rainbow(np.linspace(0, 1, len(set(df.trip_id))))
plt.scatter(df.trip_id)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [8], line 3
#       1 colors = cm.rainbow(np.linspace(0, 1, len(df.trip_id)))
#       2 for x, y, c in zip(df.stop_sequence, df.stop_id, colors):
# ----> 3     plt.scatter(x,y, color=c)
#
# File ~/anaconda3/envs/equitable-transport-reduction/lib/python3.9/site-packages/matplotlib/pyplot.py:2778, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2773 @_copy_docstring_and_deprecators(Axes.scatter)
#    2774 def scatter(
#    2775         x, y, s=None, c=None, marker=None, cmap=None, norm=None,
#    2776         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2777         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2778     __ret = gca().scatter(
#    2779         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
# ...
