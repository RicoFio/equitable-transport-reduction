# %%
import geopandas as gpd
from pathlib import Path
import pandas as pd
from shapely.geometry import Point, LineString, shape

# %%
shapes = pd.read_csv(Path('./full_gtfs_amsterdam_11_10_2022-filtered-by-GVB_IFF:GVB_IFF:NS_IFF:NSI_IFF:RNET/shapes.txt'))
shapes
# Out:
#         shape_id  shape_pt_lat  shape_pt_lon  shape_pt_sequence  \
# 0        1005038      52.33611       4.88936                  0
# 1        1005038      52.33610       4.88945                  3
# 2        1005038      52.33610       4.88954                  6
# 3        1005038      52.33612       4.88963                  9
# 4        1005038      52.33614       4.88970                 12
# ...          ...           ...           ...                ...
# 189171    992619      52.39765       4.89065                 51
# 189172    992619      52.39820       4.89055                 54
# 189173    992619      52.39845       4.89065                 57
# 189174    992619      52.39881       4.89083                 60
# 189175    992619      52.40094       4.89173                 63
#
#         shape_dist_traveled
# 0                       0.0
# 1                       6.0
# 2                      12.0
# 3                      18.0
# 4                      24.0
# ...

# %%
shapes['geometry'] = gpd.points_from_xy(shapes.shape_pt_lon, shapes.shape_pt_lat)

# %%
df = gpd.GeoDataFrame(shapes, crs=4326)

# %%
df[df.shape_id==1005038].explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
gdf = df.groupby('shape_id')['geometry'].apply(lambda x: LineString(x.tolist()))

# %%
gdf
# Out:
# shape_id
# 909316     LINESTRING (4.90104 52.37772, 4.90095 52.37774...
# 923782     LINESTRING (5.00487 52.35113, 5.00488 52.35113...
# 923783     LINESTRING (4.90104 52.37772, 4.90089 52.37775...
# 944173     LINESTRING (4.87921 52.33189, 4.87920 52.33196...
# 944190     LINESTRING (4.88645 52.39311, 4.88941 52.39448...
#                                  ...
# 1059169    LINESTRING (4.32259 52.06964, 4.32005 52.06851...
# 1059170    LINESTRING (4.66832 51.80717, 4.66563 51.80748...
# 1059171    LINESTRING (4.66832 51.80717, 4.66563 51.80748...
# 1059172    LINESTRING (4.51935 51.89376, 4.51965 51.89343...
# 1059173    LINESTRING (4.46889 51.92499, 4.46923 51.92506...
# Name: geometry, Length: 528, dtype: geometry

# %%
stdf = pd.read_csv(Path('./full_gtfs_amsterdam_11_10_2022-filtered-by-GVB_IFF:GVB_IFF:NS_IFF:NSI_IFF:RNET/stop_times.txt'))

# %%
stdf
# Out:
#            trip_id arrival_time departure_time  stop_id  stop_sequence  \
# 0        158023979     04:49:00       04:49:00    14812              1
# 1        158023979     04:49:30       04:49:48    15400              2
# 2        158023979     04:50:48       04:51:06    14845              3
# 3        158023979     04:51:16       04:51:17    14843              4
# 4        158023979     04:52:14       04:52:32   680575              5
# ...            ...          ...            ...      ...            ...
# 1054307  151824757     11:24:00       11:24:00  1762389              2
# 1054308  151824458     17:07:00       17:07:00   239520              1
# 1054309  151824458     17:12:00       17:12:00  1762389              2
# 1054310  151825605     12:13:00       12:13:00  1762389              1
# 1054311  151825605     12:18:00       12:18:00   239520              2
#
#          stop_headsign  pickup_type  drop_off_type  shape_dist_traveled  \
# ...

# %%
sdf = pd.read_csv(Path('./full_gtfs_amsterdam_11_10_2022-filtered-by-GVB_IFF:GVB_IFF:NS_IFF:NSI_IFF:RNET/stops.txt'))

# %%
sdf
# Out:
#               stop_id                    stop_name stop_code  stop_desc  \
# 0      stoparea:37036                 Lille Europe    lillee        NaN
# 1      stoparea:18059         Groningen Europapark      gerp        NaN
# 2     stoparea:111951               Bunde (Westf.)    buende        NaN
# 3     stoparea:345453          Amersfoort Centraal       amf        NaN
# 4     stoparea:177367  Brussels Airport - Zaventem      fbnl        NaN
# ...               ...                          ...       ...        ...
# 3884          2422200                       Zwolle       NaN        NaN
# 3885          2423440                        Arkel       NaN        NaN
# 3886          2324791                      Zutphen       NaN        NaN
# 3887          2323602                    Enkhuizen       NaN        NaN
# 3888          2422305                  Barendrecht       NaN        NaN
#
#        stop_lat  stop_lon  zone_id  stop_url  location_type  parent_station  \
# ...
